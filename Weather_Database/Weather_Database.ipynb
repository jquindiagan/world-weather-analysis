# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module.
from citipy import citipy

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descr = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description" : city_descr})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | san patricio
# Processing Record 3 of Set 1 | arlit
# Processing Record 4 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 5 of Set 1 | okha
# Processing Record 6 of Set 1 | spijkenisse
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | flinders
# Processing Record 9 of Set 1 | el retorno
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | makakilo city
# Processing Record 12 of Set 1 | nizwa
# Processing Record 13 of Set 1 | am timan
# Processing Record 14 of Set 1 | odweyne
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | ormara
# Processing Record 17 of Set 1 | east london
# Processing Record 18 of Set 1 | tura
# Processing Record 19 of Set 1 | cockburn town
# Processing Record 20 of Set 1 | borlange
# City not found. Skipping...
# Processing Record 21 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 1 | norman wells
# Processing Record 23 of Set 1 | leningradskiy
# Processing Record 24 of Set 1 | souillac
# Processing Record 25 of Set 1 | avarua
# Processing Record 26 of Set 1 | saskylakh
# Processing Record 27 of Set 1 | vaini
# Processing Record 28 of Set 1 | chokurdakh
# Processing Record 29 of Set 1 | upernavik
# Processing Record 30 of Set 1 | kodiak
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | karamea
# City not found. Skipping...
# Processing Record 33 of Set 1 | arman
# Processing Record 34 of Set 1 | hithadhoo
# Processing Record 35 of Set 1 | bethel
# Processing Record 36 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 1 | dingle
# Processing Record 38 of Set 1 | brasilia de minas
# Processing Record 39 of Set 1 | bluff
# Processing Record 40 of Set 1 | yellowknife
# Processing Record 41 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 1 | illela
# Processing Record 43 of Set 1 | nikolskoye
# Processing Record 44 of Set 1 | atuona
# Processing Record 45 of Set 1 | jamestown
# Processing Record 46 of Set 1 | huilong
# Processing Record 47 of Set 1 | puerto ayora
# Processing Record 48 of Set 1 | pankrushikha
# Processing Record 49 of Set 1 | cidreira
# Processing Record 50 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 2 | nanortalik
# Processing Record 2 of Set 2 | kintampo
# Processing Record 3 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 2 | tumut
# Processing Record 5 of Set 2 | college
# Processing Record 6 of Set 2 | saint george
# Processing Record 7 of Set 2 | faanui
# Processing Record 8 of Set 2 | kaitangata
# Processing Record 9 of Set 2 | wanganui
# Processing Record 10 of Set 2 | cabo san lucas
# Processing Record 11 of Set 2 | thompson
# Processing Record 12 of Set 2 | lagos
# Processing Record 13 of Set 2 | nirasaki
# Processing Record 14 of Set 2 | yulara
# Processing Record 15 of Set 2 | touros
# Processing Record 16 of Set 2 | nabire
# Processing Record 17 of Set 2 | kavieng
# Processing Record 18 of Set 2 | hofn
# Processing Record 19 of Set 2 | bengkulu
# Processing Record 20 of Set 2 | butaritari
# Processing Record 21 of Set 2 | san juan
# Processing Record 22 of Set 2 | cumpas
# Processing Record 23 of Set 2 | ontario
# Processing Record 24 of Set 2 | pacific grove
# Processing Record 25 of Set 2 | maniitsoq
# Processing Record 26 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 27 of Set 2 | kormilovka
# Processing Record 28 of Set 2 | barrow
# Processing Record 29 of Set 2 | pevek
# Processing Record 30 of Set 2 | ahar
# Processing Record 31 of Set 2 | lebu
# Processing Record 32 of Set 2 | half moon bay
# Processing Record 33 of Set 2 | hami
# Processing Record 34 of Set 2 | andenes
# Processing Record 35 of Set 2 | puerto maldonado
# Processing Record 36 of Set 2 | olafsvik
# Processing Record 37 of Set 2 | cape town
# Processing Record 38 of Set 2 | tabulbah
# City not found. Skipping...
# Processing Record 39 of Set 2 | grand gaube
# Processing Record 40 of Set 2 | leova
# Processing Record 41 of Set 2 | port blair
# Processing Record 42 of Set 2 | muli
# Processing Record 43 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 44 of Set 2 | nova olimpia
# Processing Record 45 of Set 2 | narsaq
# Processing Record 46 of Set 2 | pochutla
# Processing Record 47 of Set 2 | hilo
# Processing Record 48 of Set 2 | kapaa
# Processing Record 49 of Set 2 | tautira
# Processing Record 50 of Set 2 | belyy yar
# Processing Record 1 of Set 3 | arraial do cabo
# Processing Record 2 of Set 3 | port alfred
# Processing Record 3 of Set 3 | talnakh
# Processing Record 4 of Set 3 | airai
# Processing Record 5 of Set 3 | belfast
# Processing Record 6 of Set 3 | bahia blanca
# Processing Record 7 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 3 | lompoc
# Processing Record 9 of Set 3 | oni
# Processing Record 10 of Set 3 | sinnamary
# Processing Record 11 of Set 3 | the valley
# Processing Record 12 of Set 3 | ponta do sol
# Processing Record 13 of Set 3 | carutapera
# Processing Record 14 of Set 3 | carnarvon
# Processing Record 15 of Set 3 | ahuimanu
# Processing Record 16 of Set 3 | pangnirtung
# Processing Record 17 of Set 3 | hervey bay
# Processing Record 18 of Set 3 | utiroa
# City not found. Skipping...
# Processing Record 19 of Set 3 | navoloki
# Processing Record 20 of Set 3 | buchanan
# Processing Record 21 of Set 3 | tuatapere
# Processing Record 22 of Set 3 | manta
# Processing Record 23 of Set 3 | albany
# Processing Record 24 of Set 3 | saldanha
# Processing Record 25 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 26 of Set 3 | hajnowka
# Processing Record 27 of Set 3 | lata
# Processing Record 28 of Set 3 | nueva loja
# Processing Record 29 of Set 3 | muros
# Processing Record 30 of Set 3 | bredasdorp
# Processing Record 31 of Set 3 | klaksvik
# Processing Record 32 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 3 | borzya
# Processing Record 34 of Set 3 | georgetown
# Processing Record 35 of Set 3 | torbay
# Processing Record 36 of Set 3 | katsuura
# Processing Record 37 of Set 3 | kahului
# Processing Record 38 of Set 3 | jalu
# Processing Record 39 of Set 3 | buala
# Processing Record 40 of Set 3 | scottsbluff
# Processing Record 41 of Set 3 | dikson
# Processing Record 42 of Set 3 | pathri
# Processing Record 43 of Set 3 | ambodifototra
# City not found. Skipping...
# Processing Record 44 of Set 3 | geraldton
# Processing Record 45 of Set 3 | isangel
# Processing Record 46 of Set 3 | rawson
# Processing Record 47 of Set 3 | iquique
# Processing Record 48 of Set 3 | san bartolome de tirajana
# Processing Record 49 of Set 3 | paragominas
# Processing Record 50 of Set 3 | tasiilaq
# Processing Record 1 of Set 4 | aklavik
# Processing Record 2 of Set 4 | namibe
# Processing Record 3 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 4 | gizo
# Processing Record 5 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 6 of Set 4 | saint-philippe
# Processing Record 7 of Set 4 | chikwawa
# Processing Record 8 of Set 4 | qaanaaq
# Processing Record 9 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 4 | eenhana
# Processing Record 11 of Set 4 | karratha
# Processing Record 12 of Set 4 | tateyama
# Processing Record 13 of Set 4 | kaduqli
# Processing Record 14 of Set 4 | cherskiy
# Processing Record 15 of Set 4 | atamanskaya
# Processing Record 16 of Set 4 | severo-kurilsk
# Processing Record 17 of Set 4 | san cristobal
# Processing Record 18 of Set 4 | yukamenskoye
# Processing Record 19 of Set 4 | coquimbo
# Processing Record 20 of Set 4 | caravelas
# Processing Record 21 of Set 4 | hermanus
# Processing Record 22 of Set 4 | abu dhabi
# Processing Record 23 of Set 4 | port lincoln
# Processing Record 24 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 4 | ofaqim
# Processing Record 27 of Set 4 | nome
# Processing Record 28 of Set 4 | port-gentil
# Processing Record 29 of Set 4 | hobart
# Processing Record 30 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 4 | liberia
# Processing Record 32 of Set 4 | san martin
# Processing Record 33 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 4 | cozumel
# Processing Record 35 of Set 4 | dranceni sat
# City not found. Skipping...
# Processing Record 36 of Set 4 | la ronge
# Processing Record 37 of Set 4 | tame
# Processing Record 38 of Set 4 | sao joao da barra
# Processing Record 39 of Set 4 | helong
# Processing Record 40 of Set 4 | aswan
# Processing Record 41 of Set 4 | katangli
# Processing Record 42 of Set 4 | fraserburgh
# Processing Record 43 of Set 4 | vila franca do campo
# Processing Record 44 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 4 | grindavik
# Processing Record 47 of Set 4 | mahebourg
# Processing Record 48 of Set 4 | bereda
# Processing Record 49 of Set 4 | ewa beach
# Processing Record 50 of Set 4 | iranshahr
# Processing Record 1 of Set 5 | olinda
# Processing Record 2 of Set 5 | ancud
# Processing Record 3 of Set 5 | hamilton
# Processing Record 4 of Set 5 | khandagayty
# Processing Record 5 of Set 5 | port victoria
# Processing Record 6 of Set 5 | chimbote
# Processing Record 7 of Set 5 | uyuni
# Processing Record 8 of Set 5 | castro
# Processing Record 9 of Set 5 | sovetskiy
# Processing Record 10 of Set 5 | sioux lookout
# Processing Record 11 of Set 5 | port elizabeth
# Processing Record 12 of Set 5 | calvinia
# Processing Record 13 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 14 of Set 5 | new norfolk
# Processing Record 15 of Set 5 | sitka
# Processing Record 16 of Set 5 | tshikapa
# Processing Record 17 of Set 5 | pozo colorado
# Processing Record 18 of Set 5 | namatanai
# Processing Record 19 of Set 5 | zaozerne
# Processing Record 20 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 21 of Set 5 | vardo
# Processing Record 22 of Set 5 | temaraia
# City not found. Skipping...
# Processing Record 23 of Set 5 | poum
# Processing Record 24 of Set 5 | altamira
# Processing Record 25 of Set 5 | pangody
# Processing Record 26 of Set 5 | praia da vitoria
# Processing Record 27 of Set 5 | roald
# Processing Record 28 of Set 5 | huittinen
# Processing Record 29 of Set 5 | puerto narino
# Processing Record 30 of Set 5 | mount gambier
# Processing Record 31 of Set 5 | evanston
# Processing Record 32 of Set 5 | longyearbyen
# Processing Record 33 of Set 5 | kendari
# Processing Record 34 of Set 5 | baglung
# Processing Record 35 of Set 5 | turukhansk
# Processing Record 36 of Set 5 | taft
# Processing Record 37 of Set 5 | port hardy
# Processing Record 38 of Set 5 | alofi
# Processing Record 39 of Set 5 | beloostrov
# Processing Record 40 of Set 5 | wundanyi
# Processing Record 41 of Set 5 | pontes e lacerda
# Processing Record 42 of Set 5 | trairi
# Processing Record 43 of Set 5 | almeirim
# Processing Record 44 of Set 5 | tuktoyaktuk
# Processing Record 45 of Set 5 | umm lajj
# Processing Record 46 of Set 5 | khatanga
# Processing Record 47 of Set 5 | lusambo
# Processing Record 48 of Set 5 | rosetta
# Processing Record 49 of Set 5 | victoria
# Processing Record 50 of Set 5 | bambous virieux
# Processing Record 1 of Set 6 | broome
# Processing Record 2 of Set 6 | colquechaca
# Processing Record 3 of Set 6 | azare
# Processing Record 4 of Set 6 | pailitas
# Processing Record 5 of Set 6 | karoi
# Processing Record 6 of Set 6 | iqaluit
# Processing Record 7 of Set 6 | masakin
# Processing Record 8 of Set 6 | iisalmi
# Processing Record 9 of Set 6 | eruwa
# Processing Record 10 of Set 6 | soe
# Processing Record 11 of Set 6 | hambantota
# Processing Record 12 of Set 6 | pascagoula
# Processing Record 13 of Set 6 | jacareacanga
# Processing Record 14 of Set 6 | la paz
# Processing Record 15 of Set 6 | almaznyy
# Processing Record 16 of Set 6 | zabolottya
# City not found. Skipping...
# Processing Record 17 of Set 6 | clyde river
# Processing Record 18 of Set 6 | fort nelson
# Processing Record 19 of Set 6 | progreso
# Processing Record 20 of Set 6 | zhanatas
# City not found. Skipping...
# Processing Record 21 of Set 6 | temiscaming
# Processing Record 22 of Set 6 | kourou
# Processing Record 23 of Set 6 | deputatskiy
# Processing Record 24 of Set 6 | shahreza
# Processing Record 25 of Set 6 | mersing
# Processing Record 26 of Set 6 | aybak
# City not found. Skipping...
# Processing Record 27 of Set 6 | salalah
# Processing Record 28 of Set 6 | arica
# Processing Record 29 of Set 6 | porto nacional
# Processing Record 30 of Set 6 | batemans bay
# Processing Record 31 of Set 6 | yanan
# City not found. Skipping...
# Processing Record 32 of Set 6 | taxisco
# Processing Record 33 of Set 6 | cayenne
# Processing Record 34 of Set 6 | krasnokamensk
# Processing Record 35 of Set 6 | mizdah
# Processing Record 36 of Set 6 | zhanaozen
# Processing Record 37 of Set 6 | warwick
# Processing Record 38 of Set 6 | kumluca
# Processing Record 39 of Set 6 | upington
# Processing Record 40 of Set 6 | omsukchan
# Processing Record 41 of Set 6 | nizhniy kuranakh
# Processing Record 42 of Set 6 | doha
# Processing Record 43 of Set 6 | roding
# Processing Record 44 of Set 6 | esperance
# Processing Record 45 of Set 6 | barreirinhas
# Processing Record 46 of Set 6 | umm kaddadah
# Processing Record 47 of Set 6 | russell
# Processing Record 48 of Set 6 | novikovo
# Processing Record 49 of Set 6 | gualdo tadino
# Processing Record 50 of Set 6 | gat
# Processing Record 1 of Set 7 | camacha
# Processing Record 2 of Set 7 | kapuskasing
# Processing Record 3 of Set 7 | canton
# Processing Record 4 of Set 7 | bilibino
# Processing Record 5 of Set 7 | port arthur
# Processing Record 6 of Set 7 | bansi
# Processing Record 7 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 8 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 9 of Set 7 | kushima
# Processing Record 10 of Set 7 | pisco
# Processing Record 11 of Set 7 | chuy
# Processing Record 12 of Set 7 | juba
# Processing Record 13 of Set 7 | pastos bons
# Processing Record 14 of Set 7 | kirakira
# Processing Record 15 of Set 7 | saurimo
# Processing Record 16 of Set 7 | nouadhibou
# Processing Record 17 of Set 7 | tulum
# Processing Record 18 of Set 7 | shingu
# Processing Record 19 of Set 7 | solsvik
# City not found. Skipping...
# Processing Record 20 of Set 7 | san quintin
# Processing Record 21 of Set 7 | ballina
# Processing Record 22 of Set 7 | chontalpa
# Processing Record 23 of Set 7 | mar del plata
# Processing Record 24 of Set 7 | provideniya
# Processing Record 25 of Set 7 | taoudenni
# Processing Record 26 of Set 7 | talaya
# Processing Record 27 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 28 of Set 7 | martapura
# Processing Record 29 of Set 7 | ostrovnoy
# Processing Record 30 of Set 7 | price
# Processing Record 31 of Set 7 | san carlos de bariloche
# Processing Record 32 of Set 7 | nizhnevartovsk
# Processing Record 33 of Set 7 | graciano sanchez
# Processing Record 34 of Set 7 | takoradi
# Processing Record 35 of Set 7 | ahipara
# Processing Record 36 of Set 7 | santa fe
# Processing Record 37 of Set 7 | sunbury
# Processing Record 38 of Set 7 | koslan
# Processing Record 39 of Set 7 | yomitan
# City not found. Skipping...
# Processing Record 40 of Set 7 | rumphi
# Processing Record 41 of Set 7 | lhokseumawe
# Processing Record 42 of Set 7 | envira
# Processing Record 43 of Set 7 | awbari
# Processing Record 44 of Set 7 | atbasar
# Processing Record 45 of Set 7 | sola
# Processing Record 46 of Set 7 | kosmynino
# Processing Record 47 of Set 7 | ustye
# Processing Record 48 of Set 7 | huetamo
# City not found. Skipping...
# Processing Record 49 of Set 7 | lavrentiya
# Processing Record 50 of Set 7 | fonte boa
# Processing Record 1 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 2 of Set 8 | kalmunai
# Processing Record 3 of Set 8 | ondorhaan
# City not found. Skipping...
# Processing Record 4 of Set 8 | tolga
# Processing Record 5 of Set 8 | changchun
# Processing Record 6 of Set 8 | hasaki
# Processing Record 7 of Set 8 | tiznit
# Processing Record 8 of Set 8 | antofagasta
# Processing Record 9 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 10 of Set 8 | kysyl-syr
# Processing Record 11 of Set 8 | shimoda
# Processing Record 12 of Set 8 | vestmannaeyjar
# Processing Record 13 of Set 8 | jerecuaro
# Processing Record 14 of Set 8 | bonthe
# Processing Record 15 of Set 8 | dzilam gonzalez
# Processing Record 16 of Set 8 | asau
# Processing Record 17 of Set 8 | rantauprapat
# Processing Record 18 of Set 8 | alice springs
# Processing Record 19 of Set 8 | fare
# Processing Record 20 of Set 8 | zhigansk
# Processing Record 21 of Set 8 | maple grove
# Processing Record 22 of Set 8 | bathsheba
# Processing Record 23 of Set 8 | foso
# Processing Record 24 of Set 8 | sainte-suzanne
# Processing Record 25 of Set 8 | kiama
# Processing Record 26 of Set 8 | broken hill
# Processing Record 27 of Set 8 | sao filipe
# Processing Record 28 of Set 8 | mount isa
# Processing Record 29 of Set 8 | aranos
# Processing Record 30 of Set 8 | luderitz
# Processing Record 31 of Set 8 | constitucion
# Processing Record 32 of Set 8 | palauig
# Processing Record 33 of Set 8 | avera
# Processing Record 34 of Set 8 | coos bay
# Processing Record 35 of Set 8 | niederkassel
# Processing Record 36 of Set 8 | aksarka
# Processing Record 37 of Set 8 | zeven
# Processing Record 38 of Set 8 | ribeira grande
# Processing Record 39 of Set 8 | bonavista
# Processing Record 40 of Set 8 | tiksi
# Processing Record 41 of Set 8 | aykhal
# Processing Record 42 of Set 8 | panjakent
# Processing Record 43 of Set 8 | treinta y tres
# Processing Record 44 of Set 8 | mountain home
# Processing Record 45 of Set 8 | kutum
# Processing Record 46 of Set 8 | kaeo
# Processing Record 47 of Set 8 | iralaya
# Processing Record 48 of Set 8 | usolye
# Processing Record 49 of Set 8 | meulaboh
# Processing Record 50 of Set 8 | lima
# Processing Record 1 of Set 9 | bar harbor
# Processing Record 2 of Set 9 | naraini
# Processing Record 3 of Set 9 | lethem
# Processing Record 4 of Set 9 | gua musang
# Processing Record 5 of Set 9 | bacalar
# Processing Record 6 of Set 9 | acapulco
# Processing Record 7 of Set 9 | sur
# Processing Record 8 of Set 9 | najran
# Processing Record 9 of Set 9 | pedernales
# Processing Record 10 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 11 of Set 9 | imbituba
# Processing Record 12 of Set 9 | rio grande
# Processing Record 13 of Set 9 | samsun
# Processing Record 14 of Set 9 | duluth
# Processing Record 15 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 9 | uruzgan
# Processing Record 17 of Set 9 | beloha
# Processing Record 18 of Set 9 | leh
# Processing Record 19 of Set 9 | manokwari
# Processing Record 20 of Set 9 | kieta
# Processing Record 21 of Set 9 | moranbah
# Processing Record 22 of Set 9 | westport
# Processing Record 23 of Set 9 | fortuna
# Processing Record 24 of Set 9 | manado
# Processing Record 25 of Set 9 | rochegda
# Processing Record 26 of Set 9 | magistralnyy
# Processing Record 27 of Set 9 | huancavelica
# Processing Record 28 of Set 9 | tomatlan
# Processing Record 29 of Set 9 | panzhihua
# Processing Record 30 of Set 9 | portland
# Processing Record 31 of Set 9 | kiruna
# Processing Record 32 of Set 9 | lagoa
# Processing Record 33 of Set 9 | ardesen
# Processing Record 34 of Set 9 | vostok
# Processing Record 35 of Set 9 | goderich
# Processing Record 36 of Set 9 | dunedin
# Processing Record 37 of Set 9 | mosquera
# Processing Record 38 of Set 9 | znamenskoye
# Processing Record 39 of Set 9 | gillette
# Processing Record 40 of Set 9 | didsbury
# Processing Record 41 of Set 9 | steinbach
# Processing Record 42 of Set 9 | cusuna
# Processing Record 43 of Set 9 | itarema
# Processing Record 44 of Set 9 | dabakala
# Processing Record 45 of Set 9 | tiruvalla
# Processing Record 46 of Set 9 | oranjemund
# Processing Record 47 of Set 9 | komsomolskiy
# Processing Record 48 of Set 9 | bombay
# Processing Record 49 of Set 9 | teneguiban
# City not found. Skipping...
# Processing Record 50 of Set 9 | natal
# Processing Record 1 of Set 10 | promissao
# Processing Record 2 of Set 10 | panjwin
# City not found. Skipping...
# Processing Record 3 of Set 10 | osuna
# Processing Record 4 of Set 10 | raga
# Processing Record 5 of Set 10 | chisindia
# Processing Record 6 of Set 10 | henties bay
# Processing Record 7 of Set 10 | celestun
# Processing Record 8 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 10 | padang
# Processing Record 11 of Set 10 | los llanos de aridane
# Processing Record 12 of Set 10 | port said
# Processing Record 13 of Set 10 | atar
# Processing Record 14 of Set 10 | korla
# Processing Record 15 of Set 10 | guerrero negro
# Processing Record 16 of Set 10 | loanda
# Processing Record 17 of Set 10 | state college
# Processing Record 18 of Set 10 | ustrzyki dolne
# Processing Record 19 of Set 10 | svetlyy
# Processing Record 20 of Set 10 | kismayo
# Processing Record 21 of Set 10 | qunduz
# Processing Record 22 of Set 10 | macapa
# Processing Record 23 of Set 10 | wanning
# Processing Record 24 of Set 10 | zambezi
# Processing Record 25 of Set 10 | kultuk
# Processing Record 26 of Set 10 | cordoba
# Processing Record 27 of Set 10 | manzanillo
# Processing Record 28 of Set 10 | salym
# Processing Record 29 of Set 10 | okhotsk
# Processing Record 30 of Set 10 | soyo
# Processing Record 31 of Set 10 | ambilobe
# Processing Record 32 of Set 10 | edmonton
# Processing Record 33 of Set 10 | saint-joseph
# Processing Record 34 of Set 10 | noumea
# Processing Record 35 of Set 10 | berlevag
# Processing Record 36 of Set 10 | washougal
# Processing Record 37 of Set 10 | erdenet
# Processing Record 38 of Set 10 | vanimo
# Processing Record 39 of Set 10 | balimo
# City not found. Skipping...
# Processing Record 40 of Set 10 | ofunato
# Processing Record 41 of Set 10 | bairnsdale
# Processing Record 42 of Set 10 | khasan
# Processing Record 43 of Set 10 | mogadishu
# Processing Record 44 of Set 10 | kuusamo
# Processing Record 45 of Set 10 | saint anthony
# Processing Record 46 of Set 10 | kushiro
# Processing Record 47 of Set 10 | san miguel
# Processing Record 48 of Set 10 | khormuj
# City not found. Skipping...
# Processing Record 49 of Set 10 | srandakan
# Processing Record 50 of Set 10 | tuim
# Processing Record 1 of Set 11 | noyabrsk
# Processing Record 2 of Set 11 | santona
# Processing Record 3 of Set 11 | eureka
# Processing Record 4 of Set 11 | puerto escondido
# Processing Record 5 of Set 11 | camabatela
# Processing Record 6 of Set 11 | lorengau
# Processing Record 7 of Set 11 | garowe
# Processing Record 8 of Set 11 | karakendzha
# City not found. Skipping...
# Processing Record 9 of Set 11 | ilulissat
# Processing Record 10 of Set 11 | epe
# Processing Record 11 of Set 11 | javanrud
# Processing Record 12 of Set 11 | vaitape
# Processing Record 13 of Set 11 | banda aceh
# Processing Record 14 of Set 11 | axim
# Processing Record 15 of Set 11 | nha trang
# Processing Record 16 of Set 11 | mezen
# Processing Record 17 of Set 11 | kamenka
# Processing Record 18 of Set 11 | luan
# Processing Record 19 of Set 11 | rio gallegos
# Processing Record 20 of Set 11 | gander
# Processing Record 21 of Set 11 | walvis bay
# Processing Record 22 of Set 11 | silver city
# Processing Record 23 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 24 of Set 11 | spornoye
# Processing Record 25 of Set 11 | kefamenanu
# Processing Record 26 of Set 11 | minuri
# Processing Record 27 of Set 11 | zaragoza
# Processing Record 28 of Set 11 | kungurtug
# Processing Record 29 of Set 11 | tutoia
# Processing Record 30 of Set 11 | bam
# Processing Record 31 of Set 11 | tahta
# Processing Record 32 of Set 11 | nusaybin
# Processing Record 33 of Set 11 | nalvo
# Processing Record 34 of Set 11 | manzhouli
# Processing Record 35 of Set 11 | mehamn
# Processing Record 36 of Set 11 | romans-sur-isere
# Processing Record 37 of Set 11 | amalapuram
# Processing Record 38 of Set 11 | vanavara
# Processing Record 39 of Set 11 | mahanoro
# Processing Record 40 of Set 11 | victor rosales
# Processing Record 41 of Set 11 | mitsamiouli
# Processing Record 42 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 43 of Set 11 | umm durman
# City not found. Skipping...
# Processing Record 44 of Set 11 | mormugao
# Processing Record 45 of Set 11 | egvekinot
# Processing Record 46 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 47 of Set 11 | vohibinany
# Processing Record 48 of Set 11 | spassk
# Processing Record 49 of Set 11 | adre
# Processing Record 50 of Set 11 | khash
# Processing Record 1 of Set 12 | bridlington
# Processing Record 2 of Set 12 | zhuhai
# Processing Record 3 of Set 12 | goias
# Processing Record 4 of Set 12 | urdoma
# Processing Record 5 of Set 12 | tari
# Processing Record 6 of Set 12 | palma di montechiaro
# Processing Record 7 of Set 12 | santa cruz
# Processing Record 8 of Set 12 | banjar
# Processing Record 9 of Set 12 | kulhudhuffushi
# Processing Record 10 of Set 12 | sindor
# Processing Record 11 of Set 12 | kenai
# Processing Record 12 of Set 12 | khryashchevka
# Processing Record 13 of Set 12 | farah
# Processing Record 14 of Set 12 | rampura
# Processing Record 15 of Set 12 | gaoual
# Processing Record 16 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 17 of Set 12 | dukat
# Processing Record 18 of Set 12 | kedrovyy
# Processing Record 19 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 20 of Set 12 | baykit
# Processing Record 21 of Set 12 | faya
# Processing Record 22 of Set 12 | sayyan
# Processing Record 23 of Set 12 | winsum
# Processing Record 24 of Set 12 | leshukonskoye
# Processing Record 25 of Set 12 | cardston
# Processing Record 26 of Set 12 | buenos aires
# Processing Record 27 of Set 12 | porto novo
# Processing Record 28 of Set 12 | constantine
# Processing Record 29 of Set 12 | cabo rojo
# Processing Record 30 of Set 12 | anadyr
# Processing Record 31 of Set 12 | bakchar
# Processing Record 32 of Set 12 | norsup
# Processing Record 33 of Set 12 | samfya
# Processing Record 34 of Set 12 | bom jardim
# Processing Record 35 of Set 12 | presidente dutra
# Processing Record 36 of Set 12 | daru
# Processing Record 37 of Set 12 | lakselv
# Processing Record 38 of Set 12 | wuchi
# Processing Record 39 of Set 12 | coihaique
# Processing Record 40 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 12 | villa del rosario
# Processing Record 42 of Set 12 | toulepleu
# City not found. Skipping...
# Processing Record 43 of Set 12 | pinawa
# Processing Record 44 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 45 of Set 12 | bay city
# Processing Record 46 of Set 12 | sumbe
# Processing Record 47 of Set 12 | santa rosalia
# Processing Record 48 of Set 12 | badaojiang
# City not found. Skipping...
# Processing Record 49 of Set 12 | chala
# Processing Record 50 of Set 12 | mudu
# Processing Record 1 of Set 13 | kloulklubed
# Processing Record 2 of Set 13 | tabou
# Processing Record 3 of Set 13 | laguna
# Processing Record 4 of Set 13 | hualmay
# Processing Record 5 of Set 13 | chermoz
# Processing Record 6 of Set 13 | nishihara
# Processing Record 7 of Set 13 | tallahassee
# Processing Record 8 of Set 13 | zhangjiakou
# Processing Record 9 of Set 13 | yarmouth
# Processing Record 10 of Set 13 | yumen
# Processing Record 11 of Set 13 | sabha
# Processing Record 12 of Set 13 | mayo
# Processing Record 13 of Set 13 | ajaccio
# Processing Record 14 of Set 13 | gannan
# Processing Record 15 of Set 13 | baijiantan
# Processing Record 16 of Set 13 | islampur
# Processing Record 17 of Set 13 | tessalit
# Processing Record 18 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 13 | huajuapan
# City not found. Skipping...
# Processing Record 20 of Set 13 | oktyabrskiy
# Processing Record 21 of Set 13 | saint-denis
# Processing Record 22 of Set 13 | newport
# Processing Record 23 of Set 13 | vagur
# Processing Record 24 of Set 13 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 25 of Set 13 | toktogul
# Processing Record 26 of Set 13 | xai-xai
# Processing Record 27 of Set 13 | san rafael
# Processing Record 28 of Set 13 | neryungri
# Processing Record 29 of Set 13 | altamirano
# Processing Record 30 of Set 13 | hokitika
# Processing Record 31 of Set 13 | ayan
# Processing Record 32 of Set 13 | huarmey
# Processing Record 33 of Set 13 | rahuri
# Processing Record 34 of Set 13 | ribas do rio pardo
# Processing Record 35 of Set 13 | acari
# Processing Record 36 of Set 13 | houma
# Processing Record 37 of Set 13 | kannangad
# Processing Record 38 of Set 13 | peniche
# Processing Record 39 of Set 13 | el faiyum
# City not found. Skipping...
# Processing Record 40 of Set 13 | innisfail
# Processing Record 41 of Set 13 | verkhnevilyuysk
# Processing Record 42 of Set 13 | mantamados
# Processing Record 43 of Set 13 | west fargo
# Processing Record 44 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 45 of Set 13 | ust-nera
# Processing Record 46 of Set 13 | swedru
# Processing Record 47 of Set 13 | raudeberg
# Processing Record 48 of Set 13 | yar-sale
# Processing Record 49 of Set 13 | codrington
# Processing Record 50 of Set 13 | ligayan
# Processing Record 1 of Set 14 | bermejo
# Processing Record 2 of Set 14 | tiruchchendur
# Processing Record 3 of Set 14 | ambalavao
# Processing Record 4 of Set 14 | ankazoabo
# Processing Record 5 of Set 14 | gibgos
# Processing Record 6 of Set 14 | kathmandu
# Processing Record 7 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 14 | bermejillo
# Processing Record 9 of Set 14 | merauke
# Processing Record 10 of Set 14 | dobryanka
# Processing Record 11 of Set 14 | teofilo otoni
# Processing Record 12 of Set 14 | labuhan
# Processing Record 13 of Set 14 | marienburg
# Processing Record 14 of Set 14 | hobyo
# Processing Record 15 of Set 14 | guajara-mirim
# City not found. Skipping...
# Processing Record 16 of Set 14 | ternate
# Processing Record 17 of Set 14 | mastung
# Processing Record 18 of Set 14 | harlingen
# Processing Record 19 of Set 14 | rujewa
# Processing Record 20 of Set 14 | port shepstone
# Processing Record 21 of Set 14 | biloela
# Processing Record 22 of Set 14 | sakaraha
# Processing Record 23 of Set 14 | port macquarie
# Processing Record 24 of Set 14 | itoman
# Processing Record 25 of Set 14 | howard springs
# Processing Record 26 of Set 14 | erenhot
# Processing Record 27 of Set 14 | singaraja
# Processing Record 28 of Set 14 | tirumala
# Processing Record 29 of Set 14 | ardistan
# City not found. Skipping...
# Processing Record 30 of Set 14 | qaqortoq
# Processing Record 31 of Set 14 | gumdag
# Processing Record 32 of Set 14 | tha bo
# Processing Record 33 of Set 14 | mizpe ramon
# City not found. Skipping...
# Processing Record 34 of Set 14 | massaguet
# Processing Record 35 of Set 14 | port pirie
# Processing Record 36 of Set 14 | karlsfeld
# Processing Record 37 of Set 14 | gurupi
# Processing Record 38 of Set 14 | den helder
# Processing Record 39 of Set 14 | road town
# Processing Record 40 of Set 14 | fairbanks
# Processing Record 41 of Set 14 | alice town
# Processing Record 42 of Set 14 | acajutla
# Processing Record 43 of Set 14 | ciudad bolivar
# Processing Record 44 of Set 14 | tual
# Processing Record 45 of Set 14 | stonewall
# Processing Record 46 of Set 14 | san ignacio
# Processing Record 47 of Set 14 | nemuro
# Processing Record 48 of Set 14 | klarup
# Processing Record 49 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 50 of Set 14 | charters towers
# Processing Record 1 of Set 15 | bowen
# Processing Record 2 of Set 15 | perdoes
# Processing Record 3 of Set 15 | nicoya
# Processing Record 4 of Set 15 | sam chuk
# Processing Record 5 of Set 15 | eyl
# Processing Record 6 of Set 15 | kavaratti
# Processing Record 7 of Set 15 | sarangani
# Processing Record 8 of Set 15 | havre-saint-pierre
# Processing Record 9 of Set 15 | barras
# Processing Record 10 of Set 15 | jiangyou
# Processing Record 11 of Set 15 | kargasok
# Processing Record 12 of Set 15 | brookfield
# Processing Record 13 of Set 15 | tilichiki
# Processing Record 14 of Set 15 | pemalang
# Processing Record 15 of Set 15 | mococa
# Processing Record 16 of Set 15 | karatau
# Processing Record 17 of Set 15 | rio verde de mato grosso
# Processing Record 18 of Set 15 | inuvik
# Processing Record 19 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 20 of Set 15 | amahai
# Processing Record 21 of Set 15 | dingzhou
# Processing Record 22 of Set 15 | bagotville
# Processing Record 23 of Set 15 | lazaro cardenas
# Processing Record 24 of Set 15 | yarovoye
# Processing Record 25 of Set 15 | mobaye
# Processing Record 26 of Set 15 | novoagansk
# Processing Record 27 of Set 15 | chilca
# Processing Record 28 of Set 15 | jardim
# Processing Record 29 of Set 15 | fiumicino
# Processing Record 30 of Set 15 | wichita falls
# Processing Record 31 of Set 15 | irsha
# Processing Record 32 of Set 15 | boa vista
# Processing Record 33 of Set 15 | mao
# Processing Record 34 of Set 15 | tchollire
# Processing Record 35 of Set 15 | maxixe
# Processing Record 36 of Set 15 | qeshm
# Processing Record 37 of Set 15 | scarborough
# Processing Record 38 of Set 15 | kitui
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 667

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Rikitea -23.1203 -134.9692     80.15        73           9
# 1   San Patricio  28.0170  -97.5169     70.07        82         100
# 2          Arlit  18.7369    7.3853     75.79        14          73
# 3           Okha  53.5739  142.9478     19.13        75          12
# 4    Spijkenisse  51.8450    4.3292     39.02        78           0
# 5   Punta Arenas -53.1500  -70.9167     44.71        87           0
# 6       Flinders -34.5833  150.8552     75.25        63          47
# 7     El Retorno   2.3302  -72.6276     72.10        99         100
# 8        Mataura -46.1927  168.8643     69.21        54          75
# 9  Makakilo City  21.3469 -158.0858     76.28        74          75
#
#    Wind Speed Country Current Description
# 0       13.24      PF          light rain
# 1       16.06      US     overcast clouds
# 2        9.93      NE       broken clouds
# 3       20.07      RU          few clouds
# 4        2.30      NL           clear sky
# 5        9.22      CL           clear sky
# 6        7.52      AU    scattered clouds
# 7        1.23      CO     overcast clouds
# 8        5.57      NZ       broken clouds
# 9        9.22      US       broken clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Rikitea      PF -23.1203 -134.9692     80.15        73           9
# 1    San Patricio      US  28.0170  -97.5169     70.07        82         100
# 2           Arlit      NE  18.7369    7.3853     75.79        14          73
# 3            Okha      RU  53.5739  142.9478     19.13        75          12
# 4     Spijkenisse      NL  51.8450    4.3292     39.02        78           0
# ..            ...     ...      ...       ...       ...       ...         ...
# 662     Tchollire      CM   8.4022   14.1698     72.05        20          97
# 663        Maxixe      MZ -23.8597   35.3472     72.45        72          93
# 664         Qeshm      IR  26.9581   56.2719     76.87        65           0
# 665   Scarborough      GB  54.2797   -0.4044     36.66        88          40
# 666         Kitui      KE  -1.3670   38.0106     67.23        72          15
#
#      Wind Speed Current Description
# 0         13.24          light rain
# 1         16.06     overcast clouds
# 2          9.93       broken clouds
# 3         20.07          few clouds
# 4          2.30           clear sky
# ..          ...                 ...
# 662        2.24     overcast clouds
# 663        6.44     overcast clouds
# 664        0.78           clear sky
# 665        3.00    scattered clouds
# 666        5.06          few clouds
#
# [667 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
